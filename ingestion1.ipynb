# %%
print('started extractig data from github : .......')

# %% [markdown]
# * `urllib.request.urlretrieve` return data,
# * the first argument is source location (file name with path)
# * second argument is temporary location with filename . it will be saved in a new file.

# %%
import urllib.request
urllib.request.urlretrieve("C:\Users\mukes\Dec_a.csv","/tmp/allevents_pipe.csv")
dbutils.fs.mv("file:/tmp/allevents_pipe.csv","dbfs:/mnt/landing/tickets/events/allevents_pipe.csv")
urllib.request.urlretrieve("https://raw.githubusercontent.com/raveendratal/PysparkTelugu/master/tickets_data/allusers_pipe.csv","/tmp/allusers_pipe.csv")
dbutils.fs.mv("file:/tmp/allusers_pipe.csv","dbfs:/mnt/landing/tickets/users/allusers_pipe.csv")
urllib.request.urlretrieve("https://raw.githubusercontent.com/raveendratal/PysparkTelugu/master/tickets_data/category_pipe.csv","/tmp/category_pipe.csv")
dbutils.fs.mv("file:/tmp/category_pipe.csv","dbfs:/mnt/landing/tickets/category/category_pipe.csv")
urllib.request.urlretrieve("https://raw.githubusercontent.com/raveendratal/PysparkTelugu/master/tickets_data/date2008_pipe.csv","/tmp/date2008_pipe.csv")
dbutils.fs.mv("file:/tmp/date2008_pipe.csv","dbfs:/mnt/landing/tickets/date/date2008_pipe.csv")
urllib.request.urlretrieve("https://raw.githubusercontent.com/raveendratal/PysparkTelugu/master/tickets_data/listings_pipe.csv","/tmp/listings_pipe.csv")
dbutils.fs.mv("file:/tmp/listings_pipe.csv","dbfs:/mnt/landing/tickets/listings/listings_pipe.csv")
urllib.request.urlretrieve("https://raw.githubusercontent.com/raveendratal/PysparkTelugu/master/tickets_data/sales_tab.csv","/tmp/sales_tab.csv")
dbutils.fs.mv("file:/tmp/sales_tab.csv","dbfs:/mnt/landing/tickets/sales/sales_tab.csv")
urllib.request.urlretrieve("https://raw.githubusercontent.com/raveendratal/PysparkTelugu/master/tickets_data/venue_pipe.csv","/tmp/venue_pipe.csv")
dbutils.fs.mv("file:/tmp/venue_pipe.csv","dbfs:/mnt/landing/tickets/venue/venue_pipe.csv")
# Out:
#   File <command-545025625558990>, line 2
#     urllib.request.urlretrieve("C:\Users\mukes\Dec_a.csv","/tmp/allevents_pipe.csv")
#                                                          ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
print('Data Extraction completed....')

# %%
dbutils.fs.ls("dbfs:/mnt/landing/tickets")
# Out:
# [FileInfo(path='dbfs:/mnt/landing/tickets/category/', name='category/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/mnt/landing/tickets/date/', name='date/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/mnt/landing/tickets/events/', name='events/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/mnt/landing/tickets/listings/', name='listings/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/mnt/landing/tickets/sales/', name='sales/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/mnt/landing/tickets/users/', name='users/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/mnt/landing/tickets/venue/', name='venue/', size=0, modificationTime=0)]

# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import col,year
#spark=SparkSession.builder.appname("mountpoint").getOrCreate()
df = spark.read.format("csv").option("delimiter","|").load("dbfs:/mnt/landing/tickets/events/allevents_pipe.csv")

# %%
display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>_c0</th><th>_c1</th><th>_c2</th><th>_c3</th><th>_c4</th><th>_c5</th></tr></thead><tbody><tr><td>EVENTID</td><td>VENUEID</td><td>CATID</td><td>DATEID</td><td>EVENTNAME</td><td>STARTTIME</td></tr><tr><td>1</td><td>305</td><td>8</td><td>1851</td><td>Gotterdammerung</td><td>2008-01-25 14:30:00</td></tr><tr><td>2</td><td>306</td><td>8</td><td>2114</td><td>Boris Godunov</td><td>2008-10-15 20:00:00</td></tr><tr><td>3</td><td>302</td><td>8</td><td>1935</td><td>Salome</td><td>2008-04-19 14:30:00</td></tr><tr><td>4</td><td>309</td><td>8</td><td>2090</td><td>La Cenerentola (Cinderella)</td><td>2008-09-21 14:30:00</td></tr><tr><td>5</td><td>302</td><td>8</td><td>1982</td><td>Il Trovatore</td><td>2008-06-05 19:00:00</td></tr><tr><td>6</td><td>308</td><td>8</td><td>2109</td><td>L Elisir d Amore</td><td>2008-10-10 19:30:00</td></tr><tr><td>7</td><td>309</td><td>8</td><td>1891</td><td>Doctor Atomic</td><td>2008-03-06 14:00: